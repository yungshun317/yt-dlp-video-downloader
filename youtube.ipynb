# %%
# !cd /home/yungshun317/workspace/py/yt-dlp-video-downloader
# !yt-dlp "https://www.youtube.com/watch?v=00GKzGyWFEs&list=PLo2EIpI_JMQtNtKNFFSMNIZwspj8H7-sQ" --paths videos/hugging_face/nlp_course --cookies-from-browser chrome
# Out:
# Extracting cookies from chrome
# Extracted 3344 cookies from chrome4304  1 files searched
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=00GKzGyWFEs&list=PLo2EIpI_JMQtNtKNFFSMNIZwspj8H7-sQ
# [youtube:tab] Downloading playlist PLo2EIpI_JMQtNtKNFFSMNIZwspj8H7-sQ - add --no-playlist to download just the video 00GKzGyWFEs
# [youtube:tab] PLo2EIpI_JMQtNtKNFFSMNIZwspj8H7-sQ: Downloading webpage
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLo2EIpI_JMQtNtKNFFSMNIZwspj8H7-sQ
# [youtube:tab] PLo2EIpI_JMQtNtKNFFSMNIZwspj8H7-sQ: Downloading webpage
# [youtube:tab] PLo2EIpI_JMQtNtKNFFSMNIZwspj8H7-sQ: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Hugging Face Course Chapter 1
# [youtube:tab] PLo2EIpI_JMQtNtKNFFSMNIZwspj8H7-sQ page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# [youtube:tab] PLo2EIpI_JMQtNtKNFFSMNIZwspj8H7-sQ page 1: Downloading API JSON
# ...

# %%
# !yt-dlp "https://www.youtube.com/watch?v=1pedAIvTWXk&list=PLo2EIpI_JMQupmYlTIrUTWD_oV-kYA3Hx&pp=iAQB" --paths videos/hugging_face/nlp_course --cookies-from-browser chrome
# Out:
# Extracting cookies from chrome
# Extracted 3344 cookies from chrome4304  1 files searched
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=1pedAIvTWXk&list=PLo2EIpI_JMQupmYlTIrUTWD_oV-kYA3Hx&pp=iAQB
# [youtube:tab] Downloading playlist PLo2EIpI_JMQupmYlTIrUTWD_oV-kYA3Hx - add --no-playlist to download just the video 1pedAIvTWXk
# [youtube:tab] PLo2EIpI_JMQupmYlTIrUTWD_oV-kYA3Hx: Downloading webpage
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLo2EIpI_JMQupmYlTIrUTWD_oV-kYA3Hx
# [youtube:tab] PLo2EIpI_JMQupmYlTIrUTWD_oV-kYA3Hx: Downloading webpage
# [youtube:tab] PLo2EIpI_JMQupmYlTIrUTWD_oV-kYA3Hx: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Hugging Face Course Chapter 2
# [youtube:tab] PLo2EIpI_JMQupmYlTIrUTWD_oV-kYA3Hx page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# [youtube:tab] PLo2EIpI_JMQupmYlTIrUTWD_oV-kYA3Hx page 1: Downloading API JSON
# ...

# %%
# !yt-dlp "https://www.youtube.com/watch?v=_BZearw7f0w&list=PLo2EIpI_JMQvbh6diTDl2TwbAyu8QWdpx&pp=iAQB" --paths videos/hugging_face/nlp_course --cookies-from-browser chrome
# Out:
# Extracting cookies from chrome
# Extracted 3344 cookies from chrome4304  1 files searched
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=_BZearw7f0w&list=PLo2EIpI_JMQvbh6diTDl2TwbAyu8QWdpx&pp=iAQB
# [youtube:tab] Downloading playlist PLo2EIpI_JMQvbh6diTDl2TwbAyu8QWdpx - add --no-playlist to download just the video _BZearw7f0w
# [youtube:tab] PLo2EIpI_JMQvbh6diTDl2TwbAyu8QWdpx: Downloading webpage
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLo2EIpI_JMQvbh6diTDl2TwbAyu8QWdpx
# [youtube:tab] PLo2EIpI_JMQvbh6diTDl2TwbAyu8QWdpx: Downloading webpage
# [youtube:tab] PLo2EIpI_JMQvbh6diTDl2TwbAyu8QWdpx: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Hugging Face Course Chapter 3: PyTorch version
# [youtube:tab] PLo2EIpI_JMQvbh6diTDl2TwbAyu8QWdpx page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# ...

# %%
# !yt-dlp "https://www.youtube.com/watch?v=XvSGPZFEjDY&list=PLo2EIpI_JMQvBf9VwoyXCkHldK6-4aGPQ&pp=iAQB" --paths videos/hugging_face/nlp_course --cookies-from-browser chrome
# Out:
# Extracting cookies from chrome
# Extracted 3344 cookies from chrome4304  1 files searched
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=XvSGPZFEjDY&list=PLo2EIpI_JMQvBf9VwoyXCkHldK6-4aGPQ&pp=iAQB
# [youtube:tab] Downloading playlist PLo2EIpI_JMQvBf9VwoyXCkHldK6-4aGPQ - add --no-playlist to download just the video XvSGPZFEjDY
# [youtube:tab] PLo2EIpI_JMQvBf9VwoyXCkHldK6-4aGPQ: Downloading webpage
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLo2EIpI_JMQvBf9VwoyXCkHldK6-4aGPQ
# [youtube:tab] PLo2EIpI_JMQvBf9VwoyXCkHldK6-4aGPQ: Downloading webpage
# [youtube:tab] PLo2EIpI_JMQvBf9VwoyXCkHldK6-4aGPQ: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Hugging Face Course Chapter 4
# [youtube:tab] PLo2EIpI_JMQvBf9VwoyXCkHldK6-4aGPQ page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# [youtube:tab] PLo2EIpI_JMQvBf9VwoyXCkHldK6-4aGPQ page 1: Downloading API JSON
# ...

# %%
# !yt-dlp "https://www.youtube.com/watch?v=HyQgpJTkRdE&list=PLo2EIpI_JMQt7wOxx6EAnXIvJMK1hoSwm&pp=iAQB" --paths videos/hugging_face/nlp_course --cookies-from-browser chrome
# Out:
# Extracting cookies from chrome
# Extracted 3343 cookies from chrome4303  1 files searched
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=HyQgpJTkRdE&list=PLo2EIpI_JMQt7wOxx6EAnXIvJMK1hoSwm&pp=iAQB
# [youtube:tab] Downloading playlist PLo2EIpI_JMQt7wOxx6EAnXIvJMK1hoSwm - add --no-playlist to download just the video HyQgpJTkRdE
# [youtube:tab] PLo2EIpI_JMQt7wOxx6EAnXIvJMK1hoSwm: Downloading webpage
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLo2EIpI_JMQt7wOxx6EAnXIvJMK1hoSwm
# [youtube:tab] PLo2EIpI_JMQt7wOxx6EAnXIvJMK1hoSwm: Downloading webpage
# [youtube:tab] PLo2EIpI_JMQt7wOxx6EAnXIvJMK1hoSwm: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Hugging Face Course Chapter 5
# [youtube:tab] PLo2EIpI_JMQt7wOxx6EAnXIvJMK1hoSwm page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# [youtube:tab] PLo2EIpI_JMQt7wOxx6EAnXIvJMK1hoSwm page 1: Downloading API JSON
# ...

# %%
# !yt-dlp "https://www.youtube.com/watch?v=g8quOxoqhHQ&list=PLo2EIpI_JMQshO8wBZ9Dp3E7Y4uiBmphN&pp=iAQB" --paths videos/hugging_face/nlp_course --cookies-from-browser chrome
# Out:
# Extracting cookies from chrome
# Extracted 3343 cookies from chrome4303  1 files searched
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=g8quOxoqhHQ&list=PLo2EIpI_JMQshO8wBZ9Dp3E7Y4uiBmphN&pp=iAQB
# [youtube:tab] Downloading playlist PLo2EIpI_JMQshO8wBZ9Dp3E7Y4uiBmphN - add --no-playlist to download just the video g8quOxoqhHQ
# [youtube:tab] PLo2EIpI_JMQshO8wBZ9Dp3E7Y4uiBmphN: Downloading webpage
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLo2EIpI_JMQshO8wBZ9Dp3E7Y4uiBmphN
# [youtube:tab] PLo2EIpI_JMQshO8wBZ9Dp3E7Y4uiBmphN: Downloading webpage
# [youtube:tab] PLo2EIpI_JMQshO8wBZ9Dp3E7Y4uiBmphN: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Hugging Face Course Chapter 6
# [youtube:tab] PLo2EIpI_JMQshO8wBZ9Dp3E7Y4uiBmphN page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# [youtube:tab] PLo2EIpI_JMQshO8wBZ9Dp3E7Y4uiBmphN page 1: Downloading API JSON
# ...

# %%
# !yt-dlp "https://www.youtube.com/watch?v=Hm8_PgVTFuc&list=PLo2EIpI_JMQtYmOWSszkfIi4sgz2NsySi&pp=iAQB" --paths videos/hugging_face/nlp_course --cookies-from-browser chrome
# Out:
# Extracting cookies from chrome
# Extracted 3343 cookies from chrome4303  1 files searched
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=Hm8_PgVTFuc&list=PLo2EIpI_JMQtYmOWSszkfIi4sgz2NsySi&pp=iAQB
# [youtube:tab] Downloading playlist PLo2EIpI_JMQtYmOWSszkfIi4sgz2NsySi - add --no-playlist to download just the video Hm8_PgVTFuc
# [youtube:tab] PLo2EIpI_JMQtYmOWSszkfIi4sgz2NsySi: Downloading webpage
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLo2EIpI_JMQtYmOWSszkfIi4sgz2NsySi
# [youtube:tab] PLo2EIpI_JMQtYmOWSszkfIi4sgz2NsySi: Downloading webpage
# [youtube:tab] PLo2EIpI_JMQtYmOWSszkfIi4sgz2NsySi: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Hugging Face Course Chapter 7
# [youtube:tab] PLo2EIpI_JMQtYmOWSszkfIi4sgz2NsySi page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# [youtube:tab] PLo2EIpI_JMQtYmOWSszkfIi4sgz2NsySi page 1: Downloading API JSON
# ...

# %%
# !yt-dlp "https://www.youtube.com/watch?v=DQ-CpJn6Rc4&list=PLo2EIpI_JMQt52mV-fylktyVtznz4SU8i&pp=iAQB" --paths videos/hugging_face/nlp_course --cookies-from-browser chrome
# Out:
# Extracting cookies from chrome
# Extracted 3343 cookies from chrome4303  1 files searched
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=DQ-CpJn6Rc4&list=PLo2EIpI_JMQt52mV-fylktyVtznz4SU8i&pp=iAQB
# [youtube:tab] Downloading playlist PLo2EIpI_JMQt52mV-fylktyVtznz4SU8i - add --no-playlist to download just the video DQ-CpJn6Rc4
# [youtube:tab] PLo2EIpI_JMQt52mV-fylktyVtznz4SU8i: Downloading webpage
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLo2EIpI_JMQt52mV-fylktyVtznz4SU8i
# [youtube:tab] PLo2EIpI_JMQt52mV-fylktyVtznz4SU8i: Downloading webpage
# [youtube:tab] PLo2EIpI_JMQt52mV-fylktyVtznz4SU8i: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Hugging Face Course Chapter 8
# [youtube:tab] PLo2EIpI_JMQt52mV-fylktyVtznz4SU8i page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# [youtube:tab] PLo2EIpI_JMQt52mV-fylktyVtznz4SU8i page 1: Downloading API JSON
# ...

# %%
# !yt-dlp "https://www.youtube.com/watch?v=W_gMJF0xomE&list=PLo2EIpI_JMQvXha8ltnkSGDfNCUE59YVm&pp=iAQB" --paths videos/hugging_face/nlp_course --cookies-from-browser chrome
# Out:
# Extracting cookies from chrome
# Extracted 3343 cookies from chrome4303  1 files searched
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=W_gMJF0xomE&list=PLo2EIpI_JMQvXha8ltnkSGDfNCUE59YVm&pp=iAQB
# [youtube:tab] Downloading playlist PLo2EIpI_JMQvXha8ltnkSGDfNCUE59YVm - add --no-playlist to download just the video W_gMJF0xomE
# [youtube:tab] PLo2EIpI_JMQvXha8ltnkSGDfNCUE59YVm: Downloading webpage
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLo2EIpI_JMQvXha8ltnkSGDfNCUE59YVm
# [youtube:tab] PLo2EIpI_JMQvXha8ltnkSGDfNCUE59YVm: Downloading webpage
# [youtube:tab] PLo2EIpI_JMQvXha8ltnkSGDfNCUE59YVm: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Hugging Face Course Chapter 3: TensorFlow version
# [youtube:tab] PLo2EIpI_JMQvXha8ltnkSGDfNCUE59YVm page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# ...
